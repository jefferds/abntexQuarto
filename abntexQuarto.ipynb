# %% [markdown]
# <!-- CONFIGURAÇÕES -->
#
# <!-- Executa script julia de inicialização -->

# %%
#| echo: false

cd(raw"./")
# println(pwd())

allfiles = [(joinpath.(folder,files) for (folder,dir,files) in walkdir(raw"./"))...;]

for a in allfiles
    if occursin(r"desktop.ini", a)
        # println("Remove $a")
        rm(a);
    end

end;

# %% [markdown]
# \ABNTEXchapterfont\normalsize
#
# <!-- PRETEXTUAIS -->
# \ABNTEXchapterfont\normalsize
#
# <!-- capa -->
# \begin{center}
# \uppercase{ {{< var tcc.universidade >}} }
#
# \uppercase{ {{< var tcc.instituto >}} }
#
# \uppercase{ {{< var tcc.faculdade >}} }
#
# \vfill
#
# \uppercase{ {{< var tcc.autor >}} }
#
# \vfill
#
# \uppercase{ {{< var tcc.titulo >}} }
#
# {{< var tcc.subtitulo >}}
#
# \vfill
#
# \uppercase{ {{< var tcc.cidade >}} }
#
# {{< var tcc.ano >}}
#
# \end{center}
#
# {{< pagebreak >}}
#
#
#
# <!-- folha de rosto -->
# \begin{center}
# \uppercase{ {{< var tcc.autor >}} }
#
# \vspace{6cm}
#
# \uppercase{ {{< var tcc.titulo >}} }
#
# {{< var tcc.subtitulo >}}
#
# \vspace{3cm}
#
# \hfill\begin{minipage}{0.5\textwidth}
# Pré-projeto de Trabalho de Conclusão de Curso (TCC) apresentado na Faculdade de Engenharia Mecânica (Femec) da Universidade Federal do Sul e Sudeste do Pará (Unifesspa) como requisito básico para a conclusão do Curso de Engenharia Mecânica.
#
# \vspace{1cm}
#
# Orientador (a): {{< var tcc.orientador >}}
#
# Coorientador (a): {{< var tcc.coorientador >}}
#
# \end{minipage}
#
# \vfill
#
# \uppercase{ {{< var tcc.cidade >}} }
#
# {{< var tcc.ano >}}
#
# \end{center}
#
# {{< pagebreak >}}
#
#
#
# <!-- ficha catalografica -->
# \begin{fichacatalografica}
# 	\vspace*{\fill}					% Posição vertical
# 	\hrule							% Linha horizontal
# 	\begin{center}					% Minipage Centralizado
# 	\begin{minipage}[c]{12.5cm}		% Largura
#
# 	{{< var tcc.autor >}}
#
# 	\hspace{0.5cm} {{< var tcc.titulo >}}  / {{< var tcc.autor >}}. --
# 	{{< var tcc.cidade >}}, {{< var tcc.ano >}}-
#
# 	\hspace{0.5cm} \pageref{LastPage} p. : il. (algumas color.) ; 30 cm.\\
#
# 	\hspace{0.5cm} {{< var tcc.orientador >}}\\
#
# 	\hspace{0.5cm}
# 	\parbox[t]{\textwidth}{{{< var tcc.tipo >}}~--~{{< var tcc.universidade >}},
# 	{{< var tcc.ano >}}.}\\
#
# 	\hspace{0.5cm}
# 		1. {{< var tcc.palavras_chave_1 >}}.
# 		2. {{< var tcc.palavras_chave_2 >}}.
# 		3. {{< var tcc.palavras_chave_3 >}}.
# 		4. {{< var tcc.palavras_chave_4 >}}.
# 		5. {{< var tcc.palavras_chave_4 >}}.
# 		I. {{< var tcc.orientador >}}.
# 		II. {{< var tcc.universidade >}}.
# 		III. {{< var tcc.faculdade >}}.
# 		IV. {{< var tcc.titulo >}}\\
#
# 	\hspace{8.75cm} CDU {{< var tcc.CDU >}}\\
#
# 	\end{minipage}
# 	\end{center}
# 	\hrule
# \end{fichacatalografica}
#
#
# {{< pagebreak >}}
#
#
#
# <!-- folha de aprovação -->
# \begin{folhadeaprovacao}
#
#   \begin{center}
#     \uppercase{ {{< var tcc.autor >}} }
#
#     \vspace*{\fill}\vspace*{\fill}
#     \begin{center}
#       \uppercase{ {{< var tcc.titulo >}} }
#       {{< var tcc.subtitulo >}}
#     \end{center}
#     \vspace*{\fill}
#
#     \hspace{.45\textwidth}
#     \begin{minipage}{.5\textwidth}
#         {{< var tcc.tipo >}} apresentado na {{< var tcc.faculdade >}} da {{< var tcc.universidade >}} como requisito básico para a conclusão do {{< var tcc.curso >}}.
#     \end{minipage}%
#     \vspace*{\fill}
#    \end{center}
#
#    Trabalho aprovado. {{< var tcc.cidade >}}, {{< var tcc.defesa.dia >}} de {{< var tcc.defesa.mes >}} de {{< var tcc.ano >}}:
#
#    \assinatura{\textbf{ {{< var tcc.orientador >}} } \\ Orientador}
#    \assinatura{\textbf{ {{< var tcc.defesa.membro_banca_1 >}} } \\ Convidado 1}
#    \assinatura{\textbf{ {{< var tcc.defesa.membro_banca_2 >}} } \\ Convidado 2}
#    %\assinatura{\textbf{ {{< var tcc.defesa.membro_banca_3 >}} } \\ Convidado 3}
#
#    \begin{center}
#     \vspace*{0.5cm}
#     {\large\imprimirlocal}
#     \par
#     {\large\imprimirdata}
#     \vspace*{1cm}
#   \end{center}
#
# \end{folhadeaprovacao}
#
# {{< pagebreak >}}
#
#
#
# <!-- dedicatoria -->
# \vspace*{\fill}
# \begin{flushright}
# \textit{Este trabalho é dedicado \\
# às crianças adultas que, quando \\
# pequenas, sonharam em se tornar \\
# cientistas.}
# \end{flushright}
#
# {{< pagebreak >}}
#
#
#
# <!-- epigrafe -->
# \vspace*{\fill}
# \begin{flushright}
# \textit{Penso, logo existo.\\
# René Descartes}
# \end{flushright}
#
# {{< pagebreak >}}
#
#
#
# <!-- agradecimentos -->
#
# \begin{agradecimentos}
#
# Agradeço primeiramente a Deus, que me deu o dom da vida e me abençoa todos os dias com o seu amor infinito. Sou grato aos meus pais que me apoiaram muito com palavras de incentivo. Agradeço aos mestres que serviram de exemplo para que eu me tornasse um profissional melhor a cada dia. Aos amigos meu muito obrigado (a), por torcerem e vibrarem com a minha conquista.
#
# \end{agradecimentos}
#
#
#
# <!-- resumo -->
#
# \begin{center}
# RESUMO
# \end{center}
#
# O Ciclo Rankine Orgânico é um processo de geração de energia que utiliza um fluido térmico orgânico, como o metano, como meio de trabalho. Ele é composto por uma série de componentes que trabalham em conjunto para converter a energia térmica do fluido em energia mecânica, que é, por sua vez, convertida em energia elétrica por meio de um gerador.
#
# \vspace{1cm}
#
# \textbf{Palavras Chaves:} Ciclo Rankine Orgânico, Metano, Geração de Energia.
#
# {{< pagebreak >}}
#
#
#
# <!-- abstract -->
#
# \begin{center}
# ABSTRACT
# \end{center}
#
# The Organic Rankine Cycle is an energy generation process that uses an organic thermal fluid, such as methane, as a working medium. It is composed of a series of components that work together to convert the thermal energy of the fluid into mechanical energy, which is in turn converted into electrical energy through a generator.
#
# \vspace{1cm}
#
# \textbf{Palavras Chaves:} Organic Rankine Cycle, Methane, Energy Generation.
#
# {{< pagebreak >}}
#
#
#
# \pdfbookmark[0]{\listfigurename}{lof}
# \listoffigures*
#
# {{< pagebreak >}}
#
# \pdfbookmark[0]{\listtablename}{lot}
# \listoftables*
#
# {{< pagebreak >}}
#
# \listoflistings
#
# {{< pagebreak >}}
#
# <!-- lista de abreviaturas e siglas -->
# \begin{siglas}
#   \item[ABNT] Associação Brasileira de Normas Técnicas
#   \item[abnTeX] ABsurdas Normas para TeX
# \end{siglas}
#
#
#
# <!-- lista de símbolos -->
# \begin{simbolos}
#   \item[ $\Gamma$ ] Letra grega Gama
#   \item[ $\Lambda$ ] Lambda
#   \item[ $\zeta$ ] Letra grega minúscula zeta
#   \item[ $\in$ ] Pertence
# \end{simbolos}
#
#
#
# <!-- sumario -->
# \pdfbookmark[0]{\contentsname}{toc}
# \tableofcontents*
# \cleardoublepage
#
# {{< pagebreak >}}
#
#
#
# <!-- TEXTUAIS -->
#
# <!-- Introdução -->
# \chapter{INTRODUÇÃO}
#
# O Quarto permite tecer o conteúdo e o código executável em um documento final. Para saber mais sobre o quarto ver <https://quarto.org>.
#
# # Uso de figuras
#
# Um exemplo de figura é a @fig-peixe abaixo.
#
# ::: {#fig-peixe layout-ncol=1}
#
# ![](figuras/images.jpg){width=300}
#
# Fonte: Google imagens
#
# Exemplo de figura: um peixe.
#
# :::
#
# ## Tabelas
#
# Tabelas são usadas para mostrar dados tabulares. Um exemplo de tabela é a @tbl-1 abaixo.
#
# | Nome | Idade | Sexo |
# |------|-------|------|
# | João | 20    | M    |
# | Maria | 25   | F    |
#
# : Exemplo de tabela: dados de pessoas {#tbl-1}
#
# ## Equações
#
# Black-Scholes (@eq-black-scholes) é um modelo matemático que busca explicar o comportamento dos derivativos financeiros, mais comumente opções:
#
# $$
# \frac{\partial \mathrm C}{ \partial \mathrm t } + \frac{1}{2}\sigma^{2} \mathrm S^{2}
# \frac{\partial^{2} \mathrm C}{\partial \mathrm C^2}
#   + \mathrm r \mathrm S \frac{\partial \mathrm C}{\partial \mathrm S}\ =
#   \mathrm r \mathrm C
# $$ {#eq-black-scholes}
#
# ## Código em Julia
#
# A seguir um código em Julia:
#
# <!-- Aqui precisei fazer uma gabiarra pois não consegui fazer o código ser executado no quarto.org corretamento. Usei o \vspace{0cm} nesse tempo funcionou. -->
#
# \vspace{0cm}
#
# ```{#lst-1 .julia lst-cap="Customers Query"}
# x = 1 + 1
# ```
#
# Este foi um exemplos do suporte a figuras, tabelas, equações e código em Julia. Para mais informações sobre o suporte a figuras, tabelas, equações e código (@lst-1) em Julia, consulte <https://quarto.org>.
#
# ```{#lst-2 .julia lst-cap="Exemplo de código em Julia"}
# x = 1 + 1
# ```
#
# Este foi um exemplos do suporte a figuras, tabelas, equações e código em Julia (@lst-2).
#
# ## Citando referências
#
# A seguir um exemplo de citação de referências:
#
# A citação de referências é feita como segue: @grote2009springer
#
#
#
# <!-- Referencial teórico -->
#
# \chapter{REFEERENCIAL TEÓRICO}
#
# \PROFESSOR{Apresentação teórica, baseada em referências bibliográficas, sobre o tema do trabalho.}
#
# # Tema
#
# # Subtema
#
# ## Conceitos importantes
#
# ## Etc
#
#
#
#
# <!-- Metodologia -->
# \chapter{METODOLOGIA}
#
# \PROFESSOR{Descrição do que foi feito no trabalho.}
#
#
#
# <!-- Resultados e discussões -->
#
# \chapter{Resultados e discussões}
#
# \PROFESSOR{Resultados obtidos e o que eles significam.}
#
#
#
# <!-- Conclusões -->
#
# \chapter{Conclusão}
#
# \PROFESSOR{Conclusões encontradas no trabalho}
#
#
#
# <!-- Trabalhos futuros -->
#
# \chapter{Trabalhos Futuros}
#
#
#
# \chapter{REFERÊNCIAS}
